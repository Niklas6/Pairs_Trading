# %%
import pandas as pd

prices_analysis = pd.read_csv("semiconductor_close_analysis.csv", index_col="date", parse_dates=True).sort_index()
prices_trade = pd.read_csv("semiconductor_close_trade.csv", index_col="date", parse_dates=True).sort_index()
categories = pd.read_csv("categories.csv", index_col="ticker")

# %%
def execution(df,signal):
    signal, readjust =signal_generator()
    pos=[0,0]
    revenue=0
    trades=0
    for t in stock1.index:
        y1=stock1[t]
        y2=stock2[t]
        npos=signal(pos, y1, y2, gamma)
        if npos!=pos:
            revenue+=y1*(pos[0]-npos[0])+y2*(pos[1]-npos[1])
            pos=npos
            trades +=1
        revenue +=y1*pos[0]+y2*pos[1]
    return revenue, trades
